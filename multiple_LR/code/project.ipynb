# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('../data/50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
profit_by_state = df.groupby('State')['Profit'].sum()
print(profit_by_state)
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %%
x=df.iloc[:,:3]
y=df.iloc[:,4]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50 entries, 0 to 49
# Series name: Profit
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     float64
# dtypes: float64(1)
# memory usage: 532.0 bytes

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
# dtypes: float64(3)
# memory usage: 1.3 KB

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(type(x_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_true=y_test,y_pred=y_pred)
mse
# Out:
# 80926321.22295167

# %%
r2e=r2_score(y_true=y_test,y_pred=y_pred)
r2e
# Out:
# 0.900065308303732

# %% [markdown]
# the r2 score is very low and therefore we have to scale the data so that we can get a better a r2 score

# %%
scaler=StandardScaler()
scaler.fit(x_train)
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
lr=LinearRegression()
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
yp=lr.predict(x_test_scaled)
mse=mean_squared_error(y_true=y_test,y_pred=yp)
mse
# Out:
# 80926321.22295149

# %%
r2s=r2_score(y_true=y_test,y_pred=yp)
r2s
# Out:
# 0.9000653083037322
